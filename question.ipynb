# %%
import numpy as np
data = np.array([[1,20,40,50,60],[2,40,50,60,50],[3,30,20,60,70],[4,50,60,40,60],[5,50,40,60,80]])
maths_marks = data[:,1]

increment = data[:,1]+5
print(increment)


print(maths_marks)
# Out:
# [25 45 35 55 55]
# [20 40 30 50 50]
