# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np ;
arr = [1,2,3,4,5]
arr
# Out:
# [1, 2, 3, 4, 5]

# %%
import numpy as np
arr = [1,2,3,4,5,6]
max = np.max(arr)
print(max)
# Out:
# 6
